# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hiring=pd.read_csv("/content/drive/MyDrive/hiring.csv")

# %%
hiring
# Out:
#   experience  test_score  interview_score  salary
# 0        NaN         8.0                9   50000
# 1        NaN         8.0                6   45000
# 2       five         6.0                7   60000
# 3        two        10.0               10   65000
# 4      seven         9.0                6   70000
# 5      three         7.0               10   62000
# 6        ten         NaN                7   72000
# 7     eleven         7.0                8   80000

# %%
#data=pd.get_dummies(hiring)
#data

# %%
hiring.fillna(value=8.0)
# Out:
#   experience  test_score  interview_score  salary
# 0        8.0         8.0                9   50000
# 1        8.0         8.0                6   45000
# 2       five         6.0                7   60000
# 3        two        10.0               10   65000
# 4      seven         9.0                6   70000
# 5      three         7.0               10   62000
# 6        ten         8.0                7   72000
# 7     eleven         7.0                8   80000

# %%
hiring.experience=hiring.experience.replace("five",5.0)
hiring.experience=hiring.experience.replace("two",2.0)
hiring.experience=hiring.experience.replace("seven",7.0)
hiring.experience=hiring.experience.replace("ten",10.0)
hiring.experience=hiring.experience.replace("eleven",11.0)
hiring.experience=hiring.experience.replace("three",3.0)

# %%
hiring
# Out:
#    experience  test_score  interview_score  salary
# 0         NaN         8.0                9   50000
# 1         NaN         8.0                6   45000
# 2         5.0         6.0                7   60000
# 3         2.0        10.0               10   65000
# 4         7.0         9.0                6   70000
# 5         3.0         7.0               10   62000
# 6        10.0         NaN                7   72000
# 7        11.0         7.0                8   80000

# %%
a=hiring.fillna(value=8.0)

# %%
a
# Out:
#    experience  test_score  interview_score  salary
# 0         8.0         8.0                9   50000
# 1         8.0         8.0                6   45000
# 2         5.0         6.0                7   60000
# 3         2.0        10.0               10   65000
# 4         7.0         9.0                6   70000
# 5         3.0         7.0               10   62000
# 6        10.0         8.0                7   72000
# 7        11.0         7.0                8   80000

# %%
y=a['salary']
x=a.drop(['salary'],axis=1)

# %%
sns.heatmap(hiring.corr())

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.25)

# %%
x_test
# Out:
#    experience  test_score  interview_score
# 1         8.0         8.0                6
# 5         3.0         7.0               10

# %%
x_train
# Out:
#    experience  test_score  interview_score
# 0         8.0         8.0                9
# 7        11.0         7.0                8
# 2         5.0         6.0                7
# 4         7.0         9.0                6
# 3         2.0        10.0               10
# 6        10.0         8.0                7

# %%
y_test
# Out:
# 1    45000
# 5    62000
# Name: salary, dtype: int64

# %%
y_train
# Out:
# 0    50000
# 7    80000
# 2    60000
# 4    70000
# 3    65000
# 6    72000
# Name: salary, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(random_state=0)
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([70000, 60000])

# %%
y_pred=lr.predict(x_train)
y_pred
# Out:
# array([50000, 80000, 60000, 70000, 65000, 72000])

# %%
y_pred=lr.predict(6.0,7.0,9)
y_pred
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-abaffc853e47> in <module>
# ----> 1 y_pred=lr.predict(6.0,7.0,9)
#       2 y_pred
#
# TypeError: predict() takes 2 positional arguments but 4 were given
